# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Using%20Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    'customer_id': [101, 102, 103, 104, 105],
    'age': [25, 30, 35, 28, 40],
    'gender': ['Male', 'Female', 'Female', 'Male', 'Male'],
    'city': ['Delhi', 'Mumbai', 'Chennai', 'Kolkata', 'Pune'],
    'purchase_amount': [2000, 3000, 2500, 4000, 3500]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    customer_id  age  gender     city  purchase_amount
# 0          101   25    Male    Delhi             2000
# 1          102   30  Female   Mumbai             3000
# 2          103   35  Female  Chennai             2500
# 3          104   28    Male  Kolkata             4000
# 4          105   40    Male     Pune             3500
