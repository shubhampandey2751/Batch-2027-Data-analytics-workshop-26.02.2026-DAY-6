# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Null%20Vlaue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    'customer_id': [101, 102, 103, 104, 105],
    'age': [25, None, 35, 28, None],
    'purchase_amount': [2000, 3000, None, 4000, 3500]
}
df = pd.DataFrame(data)
print(df)
df.to_csv("customer_data.csv", index=False)
# Out:
#    customer_id   age  purchase_amount
# 0          101  25.0           2000.0
# 1          102   NaN           3000.0
# 2          103  35.0              NaN
# 3          104  28.0           4000.0
# 4          105   NaN           3500.0
